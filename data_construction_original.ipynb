# %% [markdown]
# # Setup

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from mamba2mini import Mamba2LMHeadModel
from transformers import AutoTokenizer

# %%
device = "cuda"
hf_dir = "/home/fodl/slutzky1/.cache/huggingface"
tri_dir = "/home/fodl/slutzky1/.cache/triton"
xdg_dir = "/home/fodl/slutzky1/.cache/xdg"
model_name = "state-spaces/mamba2-1.3b"

# %%
os.environ['HF_HOME'] = hf_dir
os.environ['TRITON_CACHE_DIR'] = tri_dir
os.environ['XDG_CACHE_HOME'] = xdg_dir

# %% [markdown]
# # Predict

# %%
original_data = pd.read_parquet('original_data.parquet')
original_data['true_prob'] = 0.0
original_data['false_prob'] = 0.0
original_data['hit'] = False

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neox-20b", cache_dir=hf_dir, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token

# %%
model = Mamba2LMHeadModel.from_pretrained(model_name, device=device)

# %%
torch.random.manual_seed(0)
model.eval()
temperature = 1
top_k = 0
top_p = 1
attention = False

# %%
def forward_eval(temperature, top_k, top_p, batch_start, batch_end, attention, num_to_masks=None):
    prompts = list(original_data.loc[batch_start:batch_end-1, 'prompt'].values)
    true_word = list(original_data.loc[batch_start:batch_end-1, 'target_true'].values)
    false_word = list(original_data.loc[batch_start:batch_end-1, 'target_false'].values)
    true_token = tokenizer(true_word, return_tensors="pt", padding=True)
    false_token = tokenizer(false_word, return_tensors="pt", padding=True)
    true_id = true_token.input_ids.to(device='cpu')
    false_id = false_token.input_ids.to(device='cpu')
    tokens = tokenizer(prompts, return_tensors="pt", padding=True)
    input_ids = tokens.input_ids.to(device=device)
    #attn_mask = tokens.attention_mask.to(device=device)
    max_new_length = input_ids.shape[1] + 1
    fn = lambda: model.generate_single(
        input_ids=input_ids,
        max_new_length=max_new_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        eos_token_id=tokenizer.eos_token,
        attention=attention,
        num_to_masks=num_to_masks,
    )
    out = fn()
    next_token_probs = out[-1].detach().cpu().numpy()
    row_idx = np.arange(next_token_probs.shape[0]) 
    original_data.loc[batch_start:batch_end-1, 'true_prob'] = next_token_probs[row_idx, true_id[:, 0]]
    original_data.loc[batch_start:batch_end-1, 'false_prob'] = next_token_probs[row_idx, false_id[:, 0]]
    original_data.loc[batch_start:batch_end-1, 'hit'] = original_data.loc[batch_start:batch_end-1, 'true_prob'] > original_data.loc[batch_start:batch_end-1, 'false_prob']
    print(f'Finished batch [{batch_start}:{batch_end-1}]')
    torch.cuda.empty_cache()

# %%
batch_size = 64
N = len(original_data)
batches = list(np.arange(0, N, batch_size)) + [N]

# %%
forward_eval(temperature, top_k, top_p, batches[len(batches)-2], batches[len(batches)-1], attention)
# Out:
# Finished batch [21888:21918]

# %%
for i in range(len(batches)-2):
    forward_eval(temperature, top_k, top_p, batches[i], batches[i+1], attention)
# Out:
# Finished batch [0:63]
# Finished batch [64:127]
# Finished batch [128:191]
# Finished batch [192:255]
# Finished batch [256:319]
# Finished batch [320:383]
# Finished batch [384:447]
# Finished batch [448:511]
# Finished batch [512:575]
# Finished batch [576:639]
# Finished batch [640:703]
# Finished batch [704:767]
# Finished batch [768:831]
# Finished batch [832:895]
# Finished batch [896:959]
# Finished batch [960:1023]
# Finished batch [1024:1087]
# Finished batch [1088:1151]
# Finished batch [1152:1215]
# Finished batch [1216:1279]
# Finished batch [1280:1343]
# Finished batch [1344:1407]
# Finished batch [1408:1471]
# Finished batch [1472:1535]
# Finished batch [1536:1599]
# Finished batch [1600:1663]
# Finished batch [1664:1727]
# Finished batch [1728:1791]
# Finished batch [1792:1855]
# Finished batch [1856:1919]
# Finished batch [1920:1983]
# Finished batch [1984:2047]
# Finished batch [2048:2111]
# Finished batch [2112:2175]
# Finished batch [2176:2239]
# Finished batch [2240:2303]
# Finished batch [2304:2367]
# Finished batch [2368:2431]
# Finished batch [2432:2495]
# Finished batch [2496:2559]
# Finished batch [2560:2623]
# Finished batch [2624:2687]
# Finished batch [2688:2751]
# Finished batch [2752:2815]
# Finished batch [2816:2879]
# Finished batch [2880:2943]
# Finished batch [2944:3007]
# Finished batch [3008:3071]
# Finished batch [3072:3135]
# Finished batch [3136:3199]
# Finished batch [3200:3263]
# Finished batch [3264:3327]
# Finished batch [3328:3391]
# Finished batch [3392:3455]
# Finished batch [3456:3519]
# Finished batch [3520:3583]
# Finished batch [3584:3647]
# Finished batch [3648:3711]
# Finished batch [3712:3775]
# Finished batch [3776:3839]
# Finished batch [3840:3903]
# Finished batch [3904:3967]
# Finished batch [3968:4031]
# Finished batch [4032:4095]
# Finished batch [4096:4159]
# Finished batch [4160:4223]
# Finished batch [4224:4287]
# Finished batch [4288:4351]
# Finished batch [4352:4415]
# Finished batch [4416:4479]
# Finished batch [4480:4543]
# Finished batch [4544:4607]
# Finished batch [4608:4671]
# Finished batch [4672:4735]
# Finished batch [4736:4799]
# Finished batch [4800:4863]
# Finished batch [4864:4927]
# Finished batch [4928:4991]
# Finished batch [4992:5055]
# Finished batch [5056:5119]
# Finished batch [5120:5183]
# Finished batch [5184:5247]
# Finished batch [5248:5311]
# Finished batch [5312:5375]
# Finished batch [5376:5439]
# Finished batch [5440:5503]
# Finished batch [5504:5567]
# Finished batch [5568:5631]
# Finished batch [5632:5695]
# Finished batch [5696:5759]
# Finished batch [5760:5823]
# Finished batch [5824:5887]
# Finished batch [5888:5951]
# Finished batch [5952:6015]
# Finished batch [6016:6079]
# Finished batch [6080:6143]
# Finished batch [6144:6207]
# Finished batch [6208:6271]
# Finished batch [6272:6335]
# Finished batch [6336:6399]
# Finished batch [6400:6463]
# Finished batch [6464:6527]
# Finished batch [6528:6591]
# Finished batch [6592:6655]
# Finished batch [6656:6719]
# Finished batch [6720:6783]
# Finished batch [6784:6847]
# Finished batch [6848:6911]
# Finished batch [6912:6975]
# Finished batch [6976:7039]
# Finished batch [7040:7103]
# Finished batch [7104:7167]
# Finished batch [7168:7231]
# Finished batch [7232:7295]
# Finished batch [7296:7359]
# Finished batch [7360:7423]
# Finished batch [7424:7487]
# Finished batch [7488:7551]
# Finished batch [7552:7615]
# Finished batch [7616:7679]
# Finished batch [7680:7743]
# Finished batch [7744:7807]
# Finished batch [7808:7871]
# Finished batch [7872:7935]
# Finished batch [7936:7999]
# Finished batch [8000:8063]
# Finished batch [8064:8127]
# Finished batch [8128:8191]
# Finished batch [8192:8255]
# Finished batch [8256:8319]
# Finished batch [8320:8383]
# Finished batch [8384:8447]
# Finished batch [8448:8511]
# Finished batch [8512:8575]
# Finished batch [8576:8639]
# Finished batch [8640:8703]
# Finished batch [8704:8767]
# Finished batch [8768:8831]
# Finished batch [8832:8895]
# Finished batch [8896:8959]
# Finished batch [8960:9023]
# Finished batch [9024:9087]
# Finished batch [9088:9151]
# Finished batch [9152:9215]
# Finished batch [9216:9279]
# Finished batch [9280:9343]
# Finished batch [9344:9407]
# Finished batch [9408:9471]
# Finished batch [9472:9535]
# Finished batch [9536:9599]
# Finished batch [9600:9663]
# Finished batch [9664:9727]
# Finished batch [9728:9791]
# Finished batch [9792:9855]
# Finished batch [9856:9919]
# Finished batch [9920:9983]
# Finished batch [9984:10047]
# Finished batch [10048:10111]
# Finished batch [10112:10175]
# Finished batch [10176:10239]
# Finished batch [10240:10303]
# Finished batch [10304:10367]
# Finished batch [10368:10431]
# Finished batch [10432:10495]
# Finished batch [10496:10559]
# Finished batch [10560:10623]
# Finished batch [10624:10687]
# Finished batch [10688:10751]
# Finished batch [10752:10815]
# Finished batch [10816:10879]
# Finished batch [10880:10943]
# Finished batch [10944:11007]
# Finished batch [11008:11071]
# Finished batch [11072:11135]
# Finished batch [11136:11199]
# Finished batch [11200:11263]
# Finished batch [11264:11327]
# Finished batch [11328:11391]
# Finished batch [11392:11455]
# Finished batch [11456:11519]
# Finished batch [11520:11583]
# Finished batch [11584:11647]
# Finished batch [11648:11711]
# Finished batch [11712:11775]
# Finished batch [11776:11839]
# Finished batch [11840:11903]
# Finished batch [11904:11967]
# Finished batch [11968:12031]
# Finished batch [12032:12095]
# Finished batch [12096:12159]
# Finished batch [12160:12223]
# Finished batch [12224:12287]
# Finished batch [12288:12351]
# Finished batch [12352:12415]
# Finished batch [12416:12479]
# Finished batch [12480:12543]
# Finished batch [12544:12607]
# Finished batch [12608:12671]
# Finished batch [12672:12735]
# Finished batch [12736:12799]
# Finished batch [12800:12863]
# Finished batch [12864:12927]
# Finished batch [12928:12991]
# Finished batch [12992:13055]
# Finished batch [13056:13119]
# Finished batch [13120:13183]
# Finished batch [13184:13247]
# Finished batch [13248:13311]
# Finished batch [13312:13375]
# Finished batch [13376:13439]
# Finished batch [13440:13503]
# Finished batch [13504:13567]
# Finished batch [13568:13631]
# Finished batch [13632:13695]
# Finished batch [13696:13759]
# Finished batch [13760:13823]
# Finished batch [13824:13887]
# Finished batch [13888:13951]
# Finished batch [13952:14015]
# Finished batch [14016:14079]
# Finished batch [14080:14143]
# Finished batch [14144:14207]
# Finished batch [14208:14271]
# Finished batch [14272:14335]
# Finished batch [14336:14399]
# Finished batch [14400:14463]
# Finished batch [14464:14527]
# Finished batch [14528:14591]
# Finished batch [14592:14655]
# Finished batch [14656:14719]
# Finished batch [14720:14783]
# Finished batch [14784:14847]
# Finished batch [14848:14911]
# Finished batch [14912:14975]
# Finished batch [14976:15039]
# Finished batch [15040:15103]
# Finished batch [15104:15167]
# Finished batch [15168:15231]
# Finished batch [15232:15295]
# Finished batch [15296:15359]
# Finished batch [15360:15423]
# Finished batch [15424:15487]
# Finished batch [15488:15551]
# Finished batch [15552:15615]
# Finished batch [15616:15679]
# Finished batch [15680:15743]
# Finished batch [15744:15807]
# Finished batch [15808:15871]
# Finished batch [15872:15935]
# Finished batch [15936:15999]
# Finished batch [16000:16063]
# Finished batch [16064:16127]
# Finished batch [16128:16191]
# Finished batch [16192:16255]
# Finished batch [16256:16319]
# Finished batch [16320:16383]
# Finished batch [16384:16447]
# Finished batch [16448:16511]
# Finished batch [16512:16575]
# Finished batch [16576:16639]
# Finished batch [16640:16703]
# Finished batch [16704:16767]
# Finished batch [16768:16831]
# Finished batch [16832:16895]
# Finished batch [16896:16959]
# Finished batch [16960:17023]
# Finished batch [17024:17087]
# Finished batch [17088:17151]
# Finished batch [17152:17215]
# Finished batch [17216:17279]
# Finished batch [17280:17343]
# Finished batch [17344:17407]
# Finished batch [17408:17471]
# Finished batch [17472:17535]
# Finished batch [17536:17599]
# Finished batch [17600:17663]
# Finished batch [17664:17727]
# Finished batch [17728:17791]
# Finished batch [17792:17855]
# Finished batch [17856:17919]
# Finished batch [17920:17983]
# Finished batch [17984:18047]
# Finished batch [18048:18111]
# Finished batch [18112:18175]
# Finished batch [18176:18239]
# Finished batch [18240:18303]
# Finished batch [18304:18367]
# Finished batch [18368:18431]
# Finished batch [18432:18495]
# Finished batch [18496:18559]
# Finished batch [18560:18623]
# Finished batch [18624:18687]
# Finished batch [18688:18751]
# Finished batch [18752:18815]
# Finished batch [18816:18879]
# Finished batch [18880:18943]
# Finished batch [18944:19007]
# Finished batch [19008:19071]
# Finished batch [19072:19135]
# Finished batch [19136:19199]
# Finished batch [19200:19263]
# Finished batch [19264:19327]
# Finished batch [19328:19391]
# Finished batch [19392:19455]
# Finished batch [19456:19519]
# Finished batch [19520:19583]
# Finished batch [19584:19647]
# Finished batch [19648:19711]
# Finished batch [19712:19775]
# Finished batch [19776:19839]
# Finished batch [19840:19903]
# Finished batch [19904:19967]
# Finished batch [19968:20031]
# Finished batch [20032:20095]
# Finished batch [20096:20159]
# Finished batch [20160:20223]
# Finished batch [20224:20287]
# Finished batch [20288:20351]
# Finished batch [20352:20415]
# Finished batch [20416:20479]
# Finished batch [20480:20543]
# Finished batch [20544:20607]
# Finished batch [20608:20671]
# Finished batch [20672:20735]
# Finished batch [20736:20799]
# Finished batch [20800:20863]
# Finished batch [20864:20927]
# Finished batch [20928:20991]
# Finished batch [20992:21055]
# Finished batch [21056:21119]
# Finished batch [21120:21183]
# Finished batch [21184:21247]
# Finished batch [21248:21311]
# Finished batch [21312:21375]
# Finished batch [21376:21439]
# Finished batch [21440:21503]
# Finished batch [21504:21567]
# Finished batch [21568:21631]
# Finished batch [21632:21695]
# Finished batch [21696:21759]
# Finished batch [21760:21823]
# Finished batch [21824:21887]

# %%
original_data.head()
# Out:
#                              relation           relation_prefix  \
# 0          The mother tongue of {} is      The mother tongue of
# 1      The official religion of {} is  The official religion of
# 2                             {}, the
# 3             {}, which is located in
# 4  What is the twin city of {}? It is  What is the twin city of
#
#            relation_suffix                                             prompt  \
# 0                       is          The mother tongue of Danielle Darrieux is
# 1                       is   The official religion of Edwin of Northumbria is
# 2                  {}, the                                   Toko Yasuda, the
# 3  {}, which is located in  Autonomous University of Madrid, which is loca...
# 4                  ? It is               What is the twin city of Lyon? It is
#
#   relation_id target_false_id target_true_id    target_true target_false  \
# 0        P103           Q1860           Q150         French      English
# 1        P140            Q432          Q5043   Christianity        Islam
# 2       P1303           Q5994          Q6607         guitar        piano
# 3         P17             Q34            Q29          Spain       Sweden
# 4        P190           Q1461          Q3820         Beirut       Manila
#
#                            subject     true_prob    false_prob    hit
# 0                Danielle Darrieux  9.692109e-04  6.011273e-04   True
# 1             Edwin of Northumbria  1.198434e-04  6.332863e-06   True
# 2                      Toko Yasuda  2.344575e-07  8.996081e-07  False
# 3  Autonomous University of Madrid  2.009897e-04  1.928959e-07   True
# 4                             Lyon  2.063344e-05  4.327067e-08   True

# %%
original_data['hit'].mean()
# Out:
# 0.8296455130252293

# %%
original_data.to_parquet('entire_results_original.parquet')
