# %% [markdown]
# # Setup

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from mamba2mini import Mamba2LMHeadModel
from transformers import AutoTokenizer

# %%
device = "cuda"
hf_dir = "/home/fodl/slutzky1/.cache/huggingface"
tri_dir = "/home/fodl/slutzky1/.cache/triton"
xdg_dir = "/home/fodl/slutzky1/.cache/xdg"
model_name = "state-spaces/mamba2-1.3b"

# %%
os.environ['HF_HOME'] = hf_dir
os.environ['TRITON_CACHE_DIR'] = tri_dir
os.environ['XDG_CACHE_HOME'] = xdg_dir

# %% [markdown]
# # Predict

# %%
original_data = pd.read_parquet('original_data.parquet')
original_data['true_prob'] = 0.0
original_data['false_prob'] = 0.0
original_data['hit'] = False

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neox-20b", cache_dir=hf_dir, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token

# %%
model = Mamba2LMHeadModel.from_pretrained(model_name, device=device)

# %%
torch.random.manual_seed(0)
model.eval()
temperature = 1
top_k = 0
top_p = 1
attention=True

# %%
def forward_eval(temperature, top_k, top_p, batch_start, batch_end, attention, num_to_masks=None):
    prompts = list(original_data.loc[batch_start:batch_end-1, 'prompt'].values)
    true_word = list(original_data.loc[batch_start:batch_end-1, 'target_true'].values)
    false_word = list(original_data.loc[batch_start:batch_end-1, 'target_false'].values)
    true_token = tokenizer(true_word, return_tensors="pt", padding=True)
    false_token = tokenizer(false_word, return_tensors="pt", padding=True)
    true_id = true_token.input_ids.to(device='cpu')
    false_id = false_token.input_ids.to(device='cpu')
    tokens = tokenizer(prompts, return_tensors="pt", padding=True)
    input_ids = tokens.input_ids.to(device=device)
    #attn_mask = tokens.attention_mask.to(device=device)
    max_new_length = input_ids.shape[1] + 1
    fn = lambda: model.generate_single(
        input_ids=input_ids,
        max_new_length=max_new_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        eos_token_id=tokenizer.eos_token,
        attention=attention,
        num_to_masks=num_to_masks,
    )
    out = fn()
    next_token_probs = out[-1].detach().cpu().numpy()
    row_idx = np.arange(next_token_probs.shape[0]) 
    original_data.loc[batch_start:batch_end-1, 'true_prob'] = next_token_probs[row_idx, true_id[:, 0]]
    original_data.loc[batch_start:batch_end-1, 'false_prob'] = next_token_probs[row_idx, false_id[:, 0]]
    original_data.loc[batch_start:batch_end-1, 'hit'] = original_data.loc[batch_start:batch_end-1, 'true_prob'] > original_data.loc[batch_start:batch_end-1, 'false_prob']
    print(f'Finished batch [{batch_start}:{batch_end-1}]')
    torch.cuda.empty_cache()

# %%
batch_size = 128
N = len(original_data)
batches = list(np.arange(0, N, batch_size)) + [N]

# %%
forward_eval(temperature, top_k, top_p, batches[len(batches)-2], batches[len(batches)-1], attention)
# Out:
# Finished batch [21888:21918]

# %%
for i in range(len(batches)-2):
    forward_eval(temperature, top_k, top_p, batches[i], batches[i+1], attention)
# Out:
# Finished batch [0:127]
# Finished batch [128:255]
# Finished batch [256:383]
# Finished batch [384:511]
# Finished batch [512:639]
# Finished batch [640:767]
# Finished batch [768:895]
# Finished batch [896:1023]
# Finished batch [1024:1151]
# Finished batch [1152:1279]
# Finished batch [1280:1407]
# Finished batch [1408:1535]
# Finished batch [1536:1663]
# Finished batch [1664:1791]
# Finished batch [1792:1919]
# Finished batch [1920:2047]
# Finished batch [2048:2175]
# Finished batch [2176:2303]
# Finished batch [2304:2431]
# Finished batch [2432:2559]
# Finished batch [2560:2687]
# Finished batch [2688:2815]
# Finished batch [2816:2943]
# Finished batch [2944:3071]
# Finished batch [3072:3199]
# Finished batch [3200:3327]
# Finished batch [3328:3455]
# Finished batch [3456:3583]
# Finished batch [3584:3711]
# Finished batch [3712:3839]
# Finished batch [3840:3967]
# Finished batch [3968:4095]
# Finished batch [4096:4223]
# Finished batch [4224:4351]
# Finished batch [4352:4479]
# Finished batch [4480:4607]
# Finished batch [4608:4735]
# Finished batch [4736:4863]
# Finished batch [4864:4991]
# Finished batch [4992:5119]
# Finished batch [5120:5247]
# Finished batch [5248:5375]
# Finished batch [5376:5503]
# Finished batch [5504:5631]
# Finished batch [5632:5759]
# Finished batch [5760:5887]
# Finished batch [5888:6015]
# Finished batch [6016:6143]
# Finished batch [6144:6271]
# Finished batch [6272:6399]
# Finished batch [6400:6527]
# Finished batch [6528:6655]
# Finished batch [6656:6783]
# Finished batch [6784:6911]
# Finished batch [6912:7039]
# Finished batch [7040:7167]
# Finished batch [7168:7295]
# Finished batch [7296:7423]
# Finished batch [7424:7551]
# Finished batch [7552:7679]
# Finished batch [7680:7807]
# Finished batch [7808:7935]
# Finished batch [7936:8063]
# Finished batch [8064:8191]
# Finished batch [8192:8319]
# Finished batch [8320:8447]
# Finished batch [8448:8575]
# Finished batch [8576:8703]
# Finished batch [8704:8831]
# Finished batch [8832:8959]
# Finished batch [8960:9087]
# Finished batch [9088:9215]
# Finished batch [9216:9343]
# Finished batch [9344:9471]
# Finished batch [9472:9599]
# Finished batch [9600:9727]
# Finished batch [9728:9855]
# Finished batch [9856:9983]
# Finished batch [9984:10111]
# Finished batch [10112:10239]
# Finished batch [10240:10367]
# Finished batch [10368:10495]
# Finished batch [10496:10623]
# Finished batch [10624:10751]
# Finished batch [10752:10879]
# Finished batch [10880:11007]
# Finished batch [11008:11135]
# Finished batch [11136:11263]
# Finished batch [11264:11391]
# Finished batch [11392:11519]
# Finished batch [11520:11647]
# Finished batch [11648:11775]
# Finished batch [11776:11903]
# Finished batch [11904:12031]
# Finished batch [12032:12159]
# Finished batch [12160:12287]
# Finished batch [12288:12415]
# Finished batch [12416:12543]
# Finished batch [12544:12671]
# Finished batch [12672:12799]
# Finished batch [12800:12927]
# Finished batch [12928:13055]
# Finished batch [13056:13183]
# Finished batch [13184:13311]
# Finished batch [13312:13439]
# Finished batch [13440:13567]
# Finished batch [13568:13695]
# Finished batch [13696:13823]
# Finished batch [13824:13951]
# Finished batch [13952:14079]
# Finished batch [14080:14207]
# Finished batch [14208:14335]
# Finished batch [14336:14463]
# Finished batch [14464:14591]
# Finished batch [14592:14719]
# Finished batch [14720:14847]
# Finished batch [14848:14975]
# Finished batch [14976:15103]
# Finished batch [15104:15231]
# Finished batch [15232:15359]
# Finished batch [15360:15487]
# Finished batch [15488:15615]
# Finished batch [15616:15743]
# Finished batch [15744:15871]
# Finished batch [15872:15999]
# Finished batch [16000:16127]
# Finished batch [16128:16255]
# Finished batch [16256:16383]
# Finished batch [16384:16511]
# Finished batch [16512:16639]
# Finished batch [16640:16767]
# Finished batch [16768:16895]
# Finished batch [16896:17023]
# Finished batch [17024:17151]
# Finished batch [17152:17279]
# Finished batch [17280:17407]
# Finished batch [17408:17535]
# Finished batch [17536:17663]
# Finished batch [17664:17791]
# Finished batch [17792:17919]
# Finished batch [17920:18047]
# Finished batch [18048:18175]
# Finished batch [18176:18303]
# Finished batch [18304:18431]
# Finished batch [18432:18559]
# Finished batch [18560:18687]
# Finished batch [18688:18815]
# Finished batch [18816:18943]
# Finished batch [18944:19071]
# Finished batch [19072:19199]
# Finished batch [19200:19327]
# Finished batch [19328:19455]
# Finished batch [19456:19583]
# Finished batch [19584:19711]
# Finished batch [19712:19839]
# Finished batch [19840:19967]
# Finished batch [19968:20095]
# Finished batch [20096:20223]
# Finished batch [20224:20351]
# Finished batch [20352:20479]
# Finished batch [20480:20607]
# Finished batch [20608:20735]
# Finished batch [20736:20863]
# Finished batch [20864:20991]
# Finished batch [20992:21119]
# Finished batch [21120:21247]
# Finished batch [21248:21375]
# Finished batch [21376:21503]
# Finished batch [21504:21631]
# Finished batch [21632:21759]
# Finished batch [21760:21887]

# %%
original_data.head()
# Out:
#                              relation           relation_prefix  \
# 0          The mother tongue of {} is      The mother tongue of
# 1      The official religion of {} is  The official religion of
# 2                             {}, the
# 3             {}, which is located in
# 4  What is the twin city of {}? It is  What is the twin city of
#
#            relation_suffix                                             prompt  \
# 0                       is          The mother tongue of Danielle Darrieux is
# 1                       is   The official religion of Edwin of Northumbria is
# 2                  {}, the                                   Toko Yasuda, the
# 3  {}, which is located in  Autonomous University of Madrid, which is loca...
# 4                  ? It is               What is the twin city of Lyon? It is
#
#   relation_id target_false_id target_true_id    target_true target_false  \
# 0        P103           Q1860           Q150         French      English
# 1        P140            Q432          Q5043   Christianity        Islam
# 2       P1303           Q5994          Q6607         guitar        piano
# 3         P17             Q34            Q29          Spain       Sweden
# 4        P190           Q1461          Q3820         Beirut       Manila
#
#                            subject     true_prob    false_prob    hit
# 0                Danielle Darrieux  1.331835e-03  1.001687e-03   True
# 1             Edwin of Northumbria  1.906042e-04  2.509873e-05   True
# 2                      Toko Yasuda  1.843746e-07  7.064979e-07  False
# 3  Autonomous University of Madrid  1.531762e-04  2.926238e-07   True
# 4                             Lyon  2.393651e-05  1.267107e-07   True

# %%
original_data['hit'].mean()
# Out:
# 0.8299648706601579

# %%
original_data.to_parquet('entire_results_attention.parquet')
